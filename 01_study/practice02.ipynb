# %% [markdown]
# 교재16장

# %%
from pathlib import Path
import csv

# 파일 헤더 분석
path = Path('file_datas/weather_data/sitka_weather_07-2021_simple.csv')
lines = path.read_text().splitlines()

print(path.read_text().splitlines())

reader = csv.reader(lines)
header_row = next(reader)
print(header_row)
# Out:
# ['"STATION","NAME","DATE","TAVG","TMAX","TMIN"', '"USW00025333","SITKA AIRPORT, AK US","2021-07-01",,"61","53"', '"USW00025333","SITKA AIRPORT, AK US","2021-07-02",,"60","52"', '"USW00025333","SITKA AIRPORT, AK US","2021-07-03",,"66","54"', '"USW00025333","SITKA AIRPORT, AK US","2021-07-04",,"60","55"', '"USW00025333","SITKA AIRPORT, AK US","2021-07-05",,"65","55"', '"USW00025333","SITKA AIRPORT, AK US","2021-07-06",,"59","54"', '"USW00025333","SITKA AIRPORT, AK US","2021-07-07",,"58","53"', '"USW00025333","SITKA AIRPORT, AK US","2021-07-08",,"58","53"', '"USW00025333","SITKA AIRPORT, AK US","2021-07-09",,"57","53"', '"USW00025333","SITKA AIRPORT, AK US","2021-07-10",,"60","51"', '"USW00025333","SITKA AIRPORT, AK US","2021-07-11",,"60","51"', '"USW00025333","SITKA AIRPORT, AK US","2021-07-12",,"60","54"', '"USW00025333","SITKA AIRPORT, AK US","2021-07-13",,"57","52"', '"USW00025333","SITKA AIRPORT, AK US","2021-07-14",,"58","51"', '"USW00025333","SITKA AIRPORT, AK US","2021-07-15",,"
# ...

# %%
#헤더와 위치 출력하기

for index, column_header in enumerate(header_row):
    print(index, column_header)
# Out:
# 0 STATION
# 1 NAME
# 2 DATE
# 3 TAVG
# 4 TMAX
# 5 TMIN

# %%
# 데이터 추출과 읽기

#최고 기온 추출
highs = []
for row in reader:
    high = int(row[4])
    highs.append(high)

print(highs)
# Out:
# [61, 60, 66, 60, 65, 59, 58, 58, 57, 60, 60, 60, 57, 58, 60, 61, 63, 63, 70, 64, 59, 63, 61, 58, 59, 64, 62, 70, 70, 73, 66]

# %%
plt.style.available

# %%
# 기온 그래프 그리기
from pathlib import Path
import csv
import matplotlib.pyplot as plt
from datetime import datetime

# 파일 헤더 분석
path = Path('file_datas/weather_data/sitka_weather_2021_simple.csv')
lines = path.read_text().splitlines()

print(path.read_text().splitlines())

reader = csv.reader(lines)
header_row = next(reader)
print(header_row)

#헤더와 위치 출력하기
for index, column_header in enumerate(header_row):
    print(index, column_header)

#날짜와 최고 기온 추출 #그래프에 날짜 추가하기 #두번째 데이터 추가하기
dates, highs, lows = [], [], []
for row in reader:
    current_date = datetime.strptime(row[2], '%Y-%m-%d')
    high = int(row[4])
    low = int(row[5])
    dates.append(current_date)
    highs.append(high)
    lows.append(low)


#최고 기온을 그래프로 그린다
plt.style.use('seaborn-v0_8')
fig, ax = plt.subplots()
ax.plot(dates, highs, color='red', alpha=0.5)
ax.plot(dates, lows, color='blue', alpha=0.5)
ax.fill_between(dates, lows, facecolor='blue', alpha=1)

#그래프 형식
ax.set_title("Daily High and Low Temperatures, 2021", fontsize=24)
ax.set_xlabel('', fontsize=16)
fig.autofmt_xdate()
ax.set_ylabel("Temperature (F)", fontsize=16)
ax.tick_params(labelsize=16)

plt.show()
# Out:
# ['"STATION","NAME","DATE","TAVG","TMAX","TMIN"', '"USW00025333","SITKA AIRPORT, AK US","2021-01-01",,"44","40"', '"USW00025333","SITKA AIRPORT, AK US","2021-01-02",,"44","35"', '"USW00025333","SITKA AIRPORT, AK US","2021-01-03",,"43","36"', '"USW00025333","SITKA AIRPORT, AK US","2021-01-04",,"45","39"', '"USW00025333","SITKA AIRPORT, AK US","2021-01-05",,"45","40"', '"USW00025333","SITKA AIRPORT, AK US","2021-01-06",,"44","39"', '"USW00025333","SITKA AIRPORT, AK US","2021-01-07",,"48","42"', '"USW00025333","SITKA AIRPORT, AK US","2021-01-08",,"48","37"', '"USW00025333","SITKA AIRPORT, AK US","2021-01-09",,"46","38"', '"USW00025333","SITKA AIRPORT, AK US","2021-01-10",,"46","41"', '"USW00025333","SITKA AIRPORT, AK US","2021-01-11",,"44","38"', '"USW00025333","SITKA AIRPORT, AK US","2021-01-12",,"44","34"', '"USW00025333","SITKA AIRPORT, AK US","2021-01-13",,"39","34"', '"USW00025333","SITKA AIRPORT, AK US","2021-01-14",,"47","37"', '"USW00025333","SITKA AIRPORT, AK US","2021-01-15",,"
# ...

# %%
#datetime 모듈

# %%
# 에러 확인하기

# %% [markdown]
# 전 세계 지진 데이터로 지도 만들기

# %%
from pathlib import Path
import json

path = Path('chapter_16/mapping_global_datasets/eq_data/eq_data_1_day_m1.geojson')
contents = path.read_text()
all_eq_data = json.loads(conetents)

all_eq_data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[50], line 5
#       2 import json
#       4 path = Path('chapter_16/mapping_global_datasets/eq_data/eq_data_1_day_m1.geojson')
# ----> 5 contents = path.read_text()
#       6 all_eq_data = json.loads(conetents)
#       8 all_eq_data
#
# File c:\Users\user\AppData\Local\Programs\Python\Python39\lib\pathlib.py:1266, in Path.read_text(self, encoding, errors)
#    1262 def read_text(self, encoding=None, errors=None):
#    1263     """
#    1264     Open the file in text mode, read it, and close the file.
#    1265     """
# -> 1266     with self.open(mode='r', encoding=encoding, errors=errors) as f:
#    1267         return f.read()
#
# File c:\Users\user\AppData\Local\Programs\Python\Python39\lib\pathlib.py:1252, in Path.open(self, mode, buffering, encoding, errors, newline)
# ...
